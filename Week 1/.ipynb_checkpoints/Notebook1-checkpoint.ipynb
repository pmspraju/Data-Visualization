# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(5,5,'o')
plt.ylabel("Y")
plt.xlabel("X")
plt.title("Plotting example")
plt.show()

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(5,5,'o')
plt.ylabel("Y")
plt.xlabel("X")
plt.title("Plotting example")
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0.5,1,u'Plotting example')
